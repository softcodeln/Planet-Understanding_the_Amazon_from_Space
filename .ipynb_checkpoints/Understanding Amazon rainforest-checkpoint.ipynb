# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
import pandas as pd
import numpy as np

# %%
path = Path('/kaggle/input/planet-understanding-the-amazon-from-space')
path.ls()
# Out:
# [PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/test-tif-v3'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/test-jpg-v2'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/train-tif-v2'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/train-jpg'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/test_v2_file_mapping.csv'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/sample_submission_v2.csv'),
#  PosixPath('/kaggle/input/planet-understanding-the-amazon-from-space/train_v2.csv')]

# %%
df = pd.read_csv(path/'train_v2.csv')
df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %%
tfms = get_transforms(flip_vert=True,max_lighting=0.2,max_zoom=1.05,max_warp=0.0)

# %%
np.random.seed(43)
src = ImageList.from_folder(path,'train_v2.csv', folder='train-jpg', suffix='.jpg')

# %%
np.random.seed(45)
data = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
        #Where to find the data? -> in planet 'train' folder
        .split_by_rand_pct(0.2)
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_df(label_delim=' ')
        #How to label? -> use the second column of the csv file and split the tags by ' '
        .transform(tfms, size=128)
        #Data augmentation? -> use tfms with a size of 128
        .databunch())

# %%
data.show_batch(rows=2,figsize=(8,12))

# %%
archtcre = models.resnet50

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = create_cnn(data,archtcre,metrics=[acc_02,f_score], model_dir='/tmp/models')

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.01

# %%
learn.fit_one_cycle(5,slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.140147</td>
#       <td>0.115124</td>
#       <td>0.942579</td>
#       <td>0.898129</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.114224</td>
#       <td>0.100503</td>
#       <td>0.942804</td>
#       <td>0.912604</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.106681</td>
#       <td>0.090186</td>
#       <td>0.952491</td>
#       <td>0.922013</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.097837</td>
#       <td>0.087103</td>
#       <td>0.955012</td>
#       <td>0.924880</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.093817</td>
#       <td>0.085867</td>
#       <td>0.956037</td>
#       <td>0.925057</td>
#       <td>02:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-rn50')

# %% [markdown]
# # Fine-tunning:

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5,slice(1e-5,lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.097664</td>
#       <td>0.090708</td>
#       <td>0.954438</td>
#       <td>0.920100</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.095689</td>
#       <td>0.088132</td>
#       <td>0.957788</td>
#       <td>0.923803</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.092238</td>
#       <td>0.084783</td>
#       <td>0.954424</td>
#       <td>0.925218</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.086183</td>
#       <td>0.082825</td>
#       <td>0.956378</td>
#       <td>0.926699</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.082170</td>
#       <td>0.081547</td>
#       <td>0.957926</td>
#       <td>0.928099</td>
#       <td>02:36</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-rn50')

# %%
data = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
        #Where to find the data? -> in planet 'train' folder
        .split_by_rand_pct(0.2)
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_df(label_delim=' ')
        #How to label? -> use the second column of the csv file and split the tags by ' '
        .transform(tfms, size=256)
        #Data augmentation? -> use tfms with a size of 128
        .databunch())

# %%
learn.data = data
data.train_ds[1][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-2/2

# %%
learn.fit_one_cycle(5,slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.089552</td>
#       <td>0.084880</td>
#       <td>0.959634</td>
#       <td>0.925878</td>
#       <td>04:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.089114</td>
#       <td>0.082677</td>
#       <td>0.957119</td>
#       <td>0.927472</td>
#       <td>04:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.086517</td>
#       <td>0.081219</td>
#       <td>0.959561</td>
#       <td>0.929222</td>
#       <td>04:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.083319</td>
#       <td>0.080527</td>
#       <td>0.957396</td>
#       <td>0.929601</td>
#       <td>04:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.081845</td>
#       <td>0.080004</td>
#       <td>0.959009</td>
#       <td>0.930583</td>
#       <td>04:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-256-rn50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5,slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.085737</td>
#       <td>0.082968</td>
#       <td>0.958340</td>
#       <td>0.927299</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.086376</td>
#       <td>0.084620</td>
#       <td>0.957563</td>
#       <td>0.925916</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.083605</td>
#       <td>0.081647</td>
#       <td>0.957534</td>
#       <td>0.929194</td>
#       <td>04:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.079752</td>
#       <td>0.080648</td>
#       <td>0.960179</td>
#       <td>0.929785</td>
#       <td>04:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.078366</td>
#       <td>0.080592</td>
#       <td>0.960455</td>
#       <td>0.930645</td>
#       <td>04:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %%
learn.export()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-76-fa5b61306ef3> in <module>
# ----> 1 learn.export()
#
# /opt/conda/lib/python3.6/site-packages/fastai/basic_train.py in export(self, file, destroy)
#     242             state['data'] = self.data.valid_ds.get_state(**xtra)
#     243             state['cls'] = self.__class__
# --> 244             try_save(state, self.path, file)
#     245         if destroy: self.destroy()
#     246
#
# /opt/conda/lib/python3.6/site-packages/fastai/torch_core.py in try_save(state, path, file)
#     409
#     410 def try_save(state:Dict, path:Path=None, file:PathLikeOrBinaryStream=None):
# --> 411     target = open(path/file, 'wb') if is_pathlike(file) else file
#     412     try: torch.save(state, target)
#     413     except OSError as e:
#
# OSError: [Errno 30] Read-only file system: '/kaggle/input/planet-understanding-the-amazon-from-space/export.pkl'

# %% [markdown]
# # fin

# %%
test = ImageItemList.from_folder(path/'test-jpg').add(ImageItemList.from_folder(path/'test-jpg-additional'))
len(test)

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
thresh = 0.2
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
labelled_preds[:5]

# %%
fnames = [f.name[:-4] for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image_name':fnames, 'tags':labelled_preds}, columns=['image_name', 'tags'])

# %%
df.to_csv(path/'submission.csv', index=False)
